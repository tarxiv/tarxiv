# %%
from tarxiv.alerts import IMAP

# %%
txv_imap = IMAP("imap", reporting_mode=1, debug=True)
# Out:
# 2025-08-07 15:39:19,098 - imap - INFO - {'status': 'initializing'}
# 2025-08-07 15:39:19,098 - imap - INFO - {'status': 'connecting to IMAP server'}
# 2025-08-07 15:39:19,449 - imap - INFO - {'status': 'connection success'}

# %%
# Fetch emails from the inbox
# Start the monitoring tread and poll a message
txv_imap.monitor_notices()
message, alerts = txv_imap.poll(timeout=5)
# Stop monitoring for the rest of the test
txv_imap.stop_monitoring()
# Out:
# 2025-08-07 15:39:19,460 - imap - INFO - {'status': 'starting monitoring thread'}
# Delivered-To: jacks.super.secret.santa@gmail.com
# Received: by 2002:a5d:584f:0:b0:3b7:85d5:1cb3 with SMTP id i15csp675521wrf;
#         Thu, 7 Aug 2025 05:25:06 -0700 (PDT)
# X-Received: by 2002:a05:6102:508a:b0:4ec:c60d:bc11 with SMTP id ada2fe7eead31-5037abda64fmr3145947137.14.1754569505821;
#         Thu, 07 Aug 2025 05:25:05 -0700 (PDT)
# ARC-Seal: i=1; a=rsa-sha256; t=1754569505; cv=none;
#         d=google.com; s=arc-20240605;
#         b=F9TYQC0QXEFtaylmlV5XP0jAA6TBAVuor+2O9UrGtXheOihI/rHAY8R6Fnn4+6DWmf
#          7UiboQZgIk7svFD+rcy1tGas2HrdUafq/1cyTYOf2i54f6xES3At3rx5VLY8Xv1iEGvn
#          dFV4bOb5ajPCBTvYC11buz1zmqMwXOt6ZucDHt1hEHR7y9lKaRVyHVEWx3mKkp0FZRc2
#          X/u/Evkq4SsknAvtgYd8nHRz6jYKbSD1rYYaRa2NnbDIchTFyzmL/6ywzfr9APLvxR/n
#          wsU4b0FIY0KvsPxljxif0AoYvir+zy6SSgEgYH/+CqfycVmVhXJ7bX1zlpx5kKyV4zac
#          IGTw==
# ARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20240605;
#         h=to:subject:message-id:date:from:in-reply-to:references:mime-version
#          :dkim-signature;
#         bh=Fsac7D8FlNZvrwXnh1PPRYHq0geL6JHkacoQSOexsCQ=;
#         fh=HI3hCDDW8fNOgRpjxJc8q6SNq58JNVeJSrZZflWuFcc=;
#         b=IVLvMLZIHnRqGcfuqc8oj8c+qndhwlveDKLySB/VSq5qnY/urr01aOXskpF+iWmEdr
#          iH8gExlMZCIyTrKhDHYvq8dY9Fq8+9Ni9VWNwTaFEaHtWSgvUw1VRFH8NHKHzNsLjLYa
#          13kjDMMjFSirghG2Xu8217IKYBVjevgGLEDkC5qeRFRYQwDKNqNxSHaXegpKuCcjt6uQ
#          iiQGK50zRXho2kCt6RvuTV+KU99Z1vucfQ8WuCgCpUXlhG37gf8C9s2vkePcB6Wq544j
#          YoGauUTDM3AO0pU+5bJdT/VuPPc8MVv+tVbH8X+EuvuJw9i2IEmQXGggQ+ki9sSvMyZ2
#          cl8A==;
#         dara=google.com
# ARC-Authentication-Results: i=1; mx.google.com;
#        dkim=pass header.i=@gmail.com header.s=20230601 header.b=I4wg2tZr;
#        spf=pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=tarxiv.service@gmail.com;
#        dmarc=pass (p=NONE sp=QUARANTINE dis=NONE) header.from=gmail.com;
#        dara=pass header.i=@gmail.com
# Return-Path: <tarxiv.service@gmail.com>
# Received: from mail-sor-f41.google.com (mail-sor-f41.google.com. [209.85.220.41])
#         by mx.google.com with SMTPS id a1e0cc1a2514c-88dede28872sor2420481241.4.2025.08.07.05.25.05
#         for <jacks.super.secret.santa@gmail.com>
#         (Google Transport Security);
#         Thu, 07 Aug 2025 05:25:05 -0700 (PDT)
# Received-SPF: pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) client-ip=209.85.220.41;
# Authentication-Results: mx.google.com;
#        dkim=pass header.i=@gmail.com header.s=20230601 header.b=I4wg2tZr;
#        spf=pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=tarxiv.service@gmail.com;
#        dmarc=pass (p=NONE sp=QUARANTINE dis=NONE) header.from=gmail.com;
#        dara=pass header.i=@gmail.com
# DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;
#         d=gmail.com; s=20230601; t=1754569505; x=1755174305; dara=google.com;
#         h=to:subject:message-id:date:from:in-reply-to:references:mime-version
#          :from:to:cc:subject:date:message-id:reply-to;
#         bh=Fsac7D8FlNZvrwXnh1PPRYHq0geL6JHkacoQSOexsCQ=;
#         b=I4wg2tZrcmtAoBXH7RtdbruMtBkG/WliWv2K9Vg1dKW9br+0U6eC8xq3Xq5n6sSSeB
#          LdC6EIqfhsdbUwqywb34IHFXRLodzjrB+dqi7dkTVKRLeIJrgSuoNTY8slUQUTyey1Lf
#          sE2jI2ev9aJP6Hr2uYlH0ofxw6WXPkv8bX42sL3ZvEO9ZqeDKXY8KAWTcxuSL7Ig2Diy
#          qwwslbY9lEvRjLyBrk1tqJp/QpAOgQcm1DVyf4dwaYC0NgKPI7dYVDar/wj3cggld4Z0
#          S5GLCbTNMBRa5yUluHdTa6MyzxLTBPzHhK0O1ly27JT2/A32R2Wun+KE3rQDjIdoBWGE
#          USzQ==
# X-Google-DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;
#         d=1e100.net; s=20230601; t=1754569505; x=1755174305;
#         h=to:subject:message-id:date:from:in-reply-to:references:mime-version
#          :x-gm-message-state:from:to:cc:subject:date:message-id:reply-to;
#         bh=Fsac7D8FlNZvrwXnh1PPRYHq0geL6JHkacoQSOexsCQ=;
#         b=mEjshK4dwEseuQ79Gvt375wx++OEUYojac8M9CxJoM3e/WZ831WMLtFlu8cGbVcqiP
#          rZlcv26NslER2TsZB/5cL0GyzcK1KVsIjEVHaJ9l/ywVmERw4KQZlKh3DkBCJdxSLtv8
#          SONwM4MpQ98cRYtSg8eqM7xeeMMO817KOnnPIMhHmJBYAB4GL4qJaUgilFQXqGml+Stk
#          QLLUZE0mhbOn59+DXQAoNP8TrzXuIP16nAWEiyfqTJsWdHGHLhsOoqZ2vjEtk2s/QwZ4
#          OosPDZZGX3p30RjPxboNuf2acoWcStTHAvYJDe8hAVe1kUX/FpVKBT6iltsxaTJGoxcQ
#          VAlQ==
# X-Gm-Message-State: AOJu0YwFCuIrErOVDFuGKCamLXoUieSJrlWHRHWrFKdpVbrzs2lyLPwu
# 	ZwpM2a9rNRvR/LtcYv26xNf0uUpyL+OcwK/n+L51vHMqPxrXGW/ZOPZc8UJDR6fDWfeo5LGb8CE
# 	4fDDKeWgT8nhNpMh4U4wULMhmkYvm7Y96IkOD0Qk=
# X-Gm-Gg: ASbGncujDJIPqr+1zckNewQ/pURg42/drFd7TAqoa/wNju77RgNBij9/NYlxHsdptf1
# 	JKRtPn/Cs5zypF5UsTnVAZHnP+fypdqJsaCihJjJaMSlAzUsuwxQoF8suWaspbvBR/CYf2c3Quv
# 	X+lmyaPSiR09O+Syfv3MNRVI2YmuuKmpOV1gtq1ftcXi8nS/127f6bwsi302+E6P/cvjvN332Dx
# 	8X1EA==
# X-Google-Smtp-Source: AGHT+IG1SySRPzPHWzsLk7g90SiT4GqabtQAfgQjBfltFOFFfOLw4PywxCMz87F65MyuG2rTY8zLWrZ2+2XRX5CjBQo=
# X-Received: by 2002:a05:6102:4a8c:b0:4e4:f503:666b with SMTP id
#  ada2fe7eead31-5037873e117mr3620217137.3.1754569505090; Thu, 07 Aug 2025
#  05:25:05 -0700 (PDT)
# MIME-Version: 1.0
# References: <01020198728f2a2d-3fa31d9f-eca8-4158-aa1f-b37df25c178a-000000@eu-west-1.amazonses.com>
# In-Reply-To: <01020198728f2a2d-3fa31d9f-eca8-4158-aa1f-b37df25c178a-000000@eu-west-1.amazonses.com>
# From: Tarxiv <tarxiv.service@gmail.com>
# Date: Thu, 7 Aug 2025 13:24:53 +0100
# X-Gm-Features: Ac12FXwbOt7IzGyFkBxGuZYP1QV5OzVPUa4rP5_nC1bm_x2iQUPR1GivKQEADGw
# Message-ID: <CAFE+z+5GouHyLfAng-7em_8GA8kAw1iy4ktHvvLfd+QPY57TnQ@mail.gmail.com>
# Subject: Fwd: TNS - New reports and classifications
# To: "jacks.super.secret.santa@gmail.com" <jacks.super.secret.santa@gmail.com>
# Content-Type: multipart/alternative; boundary="00000000000015af0a063bc58c78"
#
# --00000000000015af0a063bc58c78
# Content-Type: text/plain; charset="UTF-8"
#
# The following new transient/s were reported:
#
# 2025tep <https://www.wis-tns.org/object/2025tep> RA=12:49:11.074,
# DEC=+52:47:02.14, Discovery date=2025-08-03 21:06:14.112, Discovery
# mag=18.045 ABMag, Filter: wide - ATLAS, Reporter: J. Tonry, L. Denneau, H.
# Weiland, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Koorts
# (Sou..., Reporting group: ATLAS, Data source group: ATLAS
# 2025teq <https://www.wis-tns.org/object/2025teq> RA=23:10:50.353,
# DEC=-38:28:02.38, Discovery date=2025-08-03 22:49:33.312, Discovery
# mag=18.551 ABMag, Filter: orange - ATLAS, Reporter: J. Tonry, L. Denneau,
# H. Weiland, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Koorts
# (Sou..., Reporting group: ATLAS, Data source group: ATLAS
# 2025ter <https://www.wis-tns.org/object/2025ter> RA=19:18:40.066,
# DEC=-34:55:08.11, Discovery date=2025-08-03 22:06:23.040, Discovery
# mag=18.335 ABMag, Filter: orange - ATLAS, Reporter: J. Tonry, L. Denneau,
# H. Weiland, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Koorts
# (Sou..., Reporting group: ATLAS, Data source group: ATLAS
# 2025tes <https://www.wis-tns.org/object/2025tes> RA=04:50:17.972,
# DEC=+22:00:13.68, Discovery date=2025-08-03 20:14:30.000, Discovery
# mag=14.6 VegaMag, Filter: Other - , Reporter: Ziyang Mai,Zhenghan Xiong,
# Reporting group: None, Data source group: None
#
#
#
#
#
# Best Regards,
# The TNS team
#
# --00000000000015af0a063bc58c78
# Content-Type: text/html; charset="UTF-8"
# Content-Transfer-Encoding: quoted-printable
#
# <div dir=3D"ltr"><div class=3D"gmail_quote gmail_quote_container"><br>The f=
# ollowing new transient/s were reported:<br><br><a href=3D"https://www.wis-t=
# ns.org/object/2025tep" target=3D"_blank">2025tep</a> RA=3D12:49:11.074, DEC=
# =3D+52:47:02.14, Discovery date=3D2025-08-03 21:06:14.112, Discovery mag=3D=
# 18.045 ABMag, Filter: wide - ATLAS, Reporter: J. Tonry, L. Denneau, H. Weil=
# and, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Koorts (Sou..., =
# Reporting group: ATLAS, Data source group: ATLAS<br><a href=3D"https://www.=
# wis-tns.org/object/2025teq" target=3D"_blank">2025teq</a> RA=3D23:10:50.353=
# , DEC=3D-38:28:02.38, Discovery date=3D2025-08-03 22:49:33.312, Discovery m=
# ag=3D18.551 ABMag, Filter: orange - ATLAS, Reporter: J. Tonry, L. Denneau, =
# H. Weiland, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Koorts (S=
# ou..., Reporting group: ATLAS, Data source group: ATLAS<br><a href=3D"https=
# ://www.wis-tns.org/object/2025ter" target=3D"_blank">2025ter</a> RA=3D19:18=
# :40.066, DEC=3D-34:55:08.11, Discovery date=3D2025-08-03 22:06:23.040, Disc=
# overy mag=3D18.335 ABMag, Filter: orange - ATLAS, Reporter: J. Tonry, L. De=
# nneau, H. Weiland, R. Siverd (IfA, University of Hawaii), N. Erasmus, W. Ko=
# orts (Sou..., Reporting group: ATLAS, Data source group: ATLAS<br><a href=
# =3D"https://www.wis-tns.org/object/2025tes" target=3D"_blank">2025tes</a> R=
# A=3D04:50:17.972, DEC=3D+22:00:13.68, Discovery date=3D2025-08-03 20:14:30.=
# 000, Discovery mag=3D14.6 VegaMag, Filter: Other - , Reporter: Ziyang Mai,Z=
# henghan Xiong, Reporting group: None, Data source group: None<br><br><br><b=
# r><br><br>Best Regards,<br>The TNS team
# </div></div>
#
# --00000000000015af0a063bc58c78--
#
# Parsed alerts: ['2025tep', '2025tep', '2025teq', '2025teq', '2025ter', '2025ter', '2025tes', '2025tes']
# Message ID: 56
# Raw email: b'Delivered-To: jacks.super.secret.santa@gmail.com\r\nReceived: by 2002:a5d:584f:0:b0:3b7:85d5:1cb3 with SMTP id i15csp675521wrf;\r\n        Thu, 7 Aug 2025 05:25:06 -0700 (PDT)\r\nX-Received: by 2002:a05:6102:508a:b0:4ec:c60d:bc11 with SMTP id ada2fe7eead31-5037abda64fmr3145947137.14.1754569505821;\r\n        Thu, 07 Aug 2025 05:25:05 -0700 (PDT)\r\nARC-Seal: i=1; a=rsa-sha256; t=1754569505; cv=none;\r\n        d=google.com; s=arc-20240605;\r\n        b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20240605;\r\n        h=to:subject:message-id:date:from:in-reply-to:references:mime-version\r\n         :dkim-signature;\r\n        bh=Fsac7D8FlNZvrwXnh1PPRYHq0geL6JHkacoQSOexsCQ=;\r\n        fh=HI3hCDDW8fNOgRpjxJc8q6SNq58JNVeJSrZZflWuFcc=;\r\n        b=;\r\n        dara=google.com\r\nARC-Authentication-Results: i=1; mx.google.com;\r\n       dkim=pass header.i=@gmail.com header.s=20230601 header.b=I4wg2tZr;\r\n       spf=pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=tarxiv.service@gmail.com;\r\n       dmarc=pass (p=NONE sp=QUARANTINE dis=NONE) header.from=gmail.com;\r\n       dara=pass header.i=@gmail.com\r\nReturn-Path: <tarxiv.service@gmail.com>\r\nReceived: from mail-sor-f41.google.com (mail-sor-f41.google.com. [209.85.220.41])\r\n        by mx.google.com with SMTPS id a1e0cc1a2514c-88dede28872sor2420481241.4.2025.08.07.05.25.05\r\n        for <jacks.super.secret.santa@gmail.com>\r\n        (Google Transport Security);\r\n        Thu, 07 Aug 2025 05:25:05 -0700 (PDT)\r\nReceived-SPF: pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) client-ip=209.85.220.41;\r\nAuthentication-Results: mx.google.com;\r\n       dkim=pass header.i=@gmail.com header.s=20230601 header.b=I4wg2tZr;\r\n       spf=pass (google.com: domain of tarxiv.service@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=tarxiv.service@gmail.com;\r\n       dmarc=pass (p=NONE sp=QUARANTINE dis=NONE) header.from=gmail.com;\r\n       dara=pass header.i=@gmail.com\r\nDKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;\r\n        d=gmail.com; s=20230601; t=1754569505; x=1755174305; dara=google.com;\r\n        h=to:subject:message-id:date:from:in-reply-to:references:mime-version\r\n         :from:to:cc:subject:date:message-id:reply-to;\r\n        bh=Fsac7D8FlNZvrwXnh1PPRYHq0geL6JHkacoQSOexsCQ=;\r\n        b=\r\nX-Google-DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;\r\n        d=1e100.net; s=20230601; t=1754569505; x=1755174305;\r\n        h=to:subject:message-id:date:from:in-reply-to:references:mime-version\r\n         :x-gm-message-state:from:to:cc:subject:date:message-id:reply-to; ...
# 2025-08-07 15:39:19,981 - imap - DEBUG - {'status': 'received alerts', 'objects': ['2025tep', '2025tep', '2025teq', '2025teq', '2025ter', '2025ter', '2025tes', '2025tes']}
# 2025-08-07 15:39:24,010 - imap - INFO - {'status': 'stopping monitoring thread'}

# %%
if message is None or alerts is None:
    print("No new messages or alerts found.")
    exit(0)
else:
    print(f"Message: {message}")
    print(f"Alerts: {alerts}")
# Out:
# Message: 54
# Alerts: []
